# %% [markdown]
# Name - Pathan Aman Firojkhan
# College - Sanjivani COE Kopargaon
# StudentId - CT_CSI_DE_1157
#
# Summary of Assignment -
#
#     -> Loaded dataset using Pandas
#     -> Explored structure (rows, columns, types)
#     -> Handled missing values (replace them by 0)
#     -> Filtered and selected useful data
#     -> Removed duplicate records
#     -> Created new column: total_amount - using initial_price and discount
#     -> Saved cleaned dataset as CSV

# %%
import pandas as pd

df = pd.read_csv("./dataset/tshirts.csv")
df
# Out:
#     product_id                      title  \
# 0     17352320                      ether
# 1     17403950             Mast & Harbour
# 2     17404018             Mast & Harbour
# 3     22143924                Urbano Plus
# 4     14619398                    ScoldMe
# 5      8901821               UNDER ARMOUR
# 6       919032                   Roadster
# 7     18817326             Tommy Hilfiger
# 8      8426447                      WROGN
# 9     20355284                   Roadster
# 10    18818696             Tommy Hilfiger
# 11     9213113                   Roadster
# 12    13511732                       Puma
# 13    13591994                      Camey
# 14    21439050                      Kappa
# 15    13615634            U.S. Polo Assn.
# 16    13620624                   Roadster
# 17    13502414                       Puma
# 18    13621134                   Roadster
# 19    17686030          Allen Solly Tribe
# 20    13616400             Arrow New York
# ...

# %%
df.head()      # First 5 rows
# Out:
#    product_id           title  \
# 0    17352320           ether
# 1    17403950  Mast & Harbour
# 2    17404018  Mast & Harbour
# 3    22143924     Urbano Plus
# 4    14619398         ScoldMe
#
#                                  product_description  rating  ratings_count  \
# 0  Kora Collection Blue Sustainable Naturally Dye...     4.4             70
# 1          Men Mint Green Typography Printed T-shirt     4.2            200
# 2       Men Blue & White Striped Regular Fit T-shirt     3.9             72
# 3             Size Typography Printed Cotton T-shirt     3.2              6
# 4     Women Multicoloured Pack Of 2 Slim Fit T-shirt     0.0              0
#
#    initial_price  discount  final_price currency  \
# 0         1099.0      47.0  "₹1,099.00"      INR
# 1          899.0       NaN    "₹899.00"      INR
# 2          999.0       NaN    "₹999.00"      INR
# 3         1099.0      45.0  "₹1,099.00"      INR
# 4         1598.0      55.0    "₹719.00"      INR
#
# ...

# %%
df.tail()      # Last 5 rows
# Out:
#     product_id           title  \
# 34    22629260             max
# 35    19291812  Mad Over Print
# 36    19206288        FERANOID
# 37    19264534  Flying Machine
# 38    19264536  Flying Machine
#
#                                   product_description  rating  ratings_count  \
# 34          Striped Polo Collar Short Sleeves T-shirt     4.4              7
# 35             Women Black Love Wins Oversize T-shirt     4.8              5
# 36          Men Purple Henley Neck Bio Finish T-shirt     4.2             21
# 37  Men Black & White Printed Pure Cotton Slim Fit...     4.0            102
# 38  Men Rust Orange Melange Pure Cotton Slim Fit T...     3.8             60
#
#     initial_price  discount final_price currency  \
# 34          799.0      40.0   "₹479.00"      INR
# 35         1599.0      58.0   "₹671.00"      INR
# 36         1199.0      50.0   "₹599.00"      INR
# 37          999.0      61.0   "₹389.00"      INR
# 38         1299.0      61.0   "₹506.00"      INR
#
# ...

# %%
df.shape       # (rows, columns)
# Out:
# (39, 24)

# %%
df.columns     # Column names
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
df.dtypes      # Data types
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price             float64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# product_id                 0
# title                      0
# product_description        0
# rating                     0
# ratings_count              0
# initial_price              0
# discount                   7
# final_price                0
# currency                   0
# images                     0
# delivery_options           0
# product_details            0
# breadcrumbs                0
# product_specifications     0
# amount_of_stars            0
# what_customers_said        9
# seller_name               21
# sizes                      0
# videos                    29
# seller_information        21
# variations                25
# best_offer                 0
# more_offers                0
# category                   0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.shape
# Out:
# (39, 24)

# %%
df.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
df[['product_id', 'rating']]
# Out:
#     product_id  rating
# 0     17352320     4.4
# 1     17403950     4.2
# 2     17404018     3.9
# 3     22143924     3.2
# 4     14619398     0.0
# 5      8901821     4.3
# 6       919032     3.8
# 7     18817326     4.4
# 8      8426447     4.2
# 9     20355284     4.2
# 10    18818696     4.4
# 11     9213113     4.1
# 12    13511732     4.4
# 13    13591994     3.5
# 14    21439050     3.2
# 15    13615634     4.5
# 16    13620624     4.0
# 17    13502414     4.3
# 18    13621134     4.1
# 19    17686030     4.3
# 20    13616400     4.8
# 21    13480864     4.2
# 22    13622338     4.4
# 23    16295686     3.9
# 24    16298856     0.0
# 25    16277914     4.9
# 26    16292318     4.2
# 27    19201678     4.1
# 28    16923916     4.8
# 29    10143909     3.7
# 30    20085320     4.8
# 31    10555034     0.0
# 32    12987894     4.4
# 33    12953958     4.4
# 34    22629260     4.4
# 35    19291812     4.8
# 36    19206288     4.2
# 37    19264534     4.0
# 38    19264536     3.8

# %%
df[df['initial_price'] > 1000.0]
# Out:
#     product_id                      title  \
# 0     17352320                      ether
# 3     22143924                Urbano Plus
# 4     14619398                    ScoldMe
# 5      8901821               UNDER ARMOUR
# 7     18817326             Tommy Hilfiger
# 8      8426447                      WROGN
# 10    18818696             Tommy Hilfiger
# 12    13511732                       Puma
# 15    13615634            U.S. Polo Assn.
# 16    13620624                   Roadster
# 17    13502414                       Puma
# 18    13621134                   Roadster
# 19    17686030          Allen Solly Tribe
# 21    13480864                Aeropostale
# 23    16295686               Miss & Chief
# 24    16298856                   Friskers
# 25    16277914                       Parx
# 26    16292318                   Bewakoof
# 29    10143909                    CHKOKKO
# 30    20085320                    BULLMER
# 31    10555034                     Braveo
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (39, 24)

# %%
df['total_amount'] = df['initial_price'] - (df['initial_price']*(df['discount']/100))

# %%
df.to_csv("cleaned_tshirts.csv", index=False)
